# %% [markdown]
# # Aufgabe: Anagramm-Überprüfung
#
# Entwickle eine Funktion ``is_anagram()``, die überprüft, ob zwei gegebene Strings Anagramme voneinander sind. Ein Anagramm ist ein Wort oder Satz, der durch Umstellen der Buchstaben eines anderen Wortes oder Satzes gebildet wird.
#
# >**Hinweis:** Diese Aufgabe kann dir helfen die Aufgabe 'Palindrom prüfen (Einfach, 15 Punkte)' zu lösen.
#
# ## Anforderungen
#
# * Die Funktion soll zwei Strings als Eingabe nehmen und ``True`` zurückgeben, wenn die Strings Anagramme voneinander sind, und ``False``, wenn nicht.
# * Ignoriere Groß-/Kleinschreibung und Leerzeichen.
#
# ## Testfälle
#
# ```python
# print(is_anagram("Listen", "Silent")) # True (Anagramme)
# print(is_anagram("Hello", "Olelh")) # True (Anagramme)
# print(is_anagram("Programming", "Gram Ring Mop")) # True (Anagramme mit Leerzeichen)
# print(is_anagram("Python", "Java")) # False (Keine Anagramme)
# ```

# %%
# Dein Code
